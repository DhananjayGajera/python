# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,color = 'g',linewidth = 5,linestyle ='dotted' )

# %%
plt.plot(x,y,color  = 'green',linewidth = 5,linestyle = 'dashdot')

# %%
plt.plot(x,y,color = 'red',linewidth = 5,linestyle = 'dotted',)

# %%
plt.xlabel('days')
plt.ylabel('temperature')
plt.title("weather")
plt.plot(x,y,color = 'y',linewidth = 5,linestyle = 'dashdot',)

# %%
#format string used in 2d plot  ,any kind of chart
plt.plot(x,y,'g+') # specfied  format string as 3rd argument / 3rd argumen you have tomantion colorlateer and simbol

# %%
plt.plot(x,y,'g+--')

# %%
# 
plt.plot(x,y,'--r+')

# %%
plt.plot(x,y,'rd') # d = diamond(marker)

# %%
# WE can also print in this format
plt.plot(x,y,color = 'red',marker = 'D',linestyle = 'dotted')

# %%
#NOTE = format string work as 3 argument color,marker,linestyle, alpha control the transprency of the line
# value of alpha  b/w  0 to 1

# %%
plt.plot(x,y,color = 'red',marker = '+',linewidth = 3,linestyle = '-',markersize = '10',alpha = 0.5)

# %% [markdown]
# # AXIS LABEL,legend,grid

# %%
max_t = [50,51,52,48,47,49,46]
min_t = [43,42,40,44,33,35,37]
avg_t = [45,38,48,42,41,42,43]
days = [1,2,3,4,5,6,7]

# %%
plt.xlabel('days')
plt.ylabel('temperature')
plt.title('weather')
# Out:
# Text(0.5, 1.0, 'weather')

# %%
plt.xlabel('days')
plt.ylabel('temperature')
plt.title('weather')

plt.plot(days,max_t)
plt.plot(days,min_t)
plt.plot(days,avg_t)

# %%
plt.xlabel('days')
plt.ylabel('temperature')
plt.title('weather')
plt.plot(days,max_t,label = 'Max')
plt.plot(days,min_t,label = 'Min')
plt.plot(days,avg_t,label = 'Avg')
plt.legend()

# %%
plt.xlabel('days')
plt.ylabel("temperature")
plt.title('weather')
plt.plot(days,max_t,label = 'Max')
plt.plot(days,min_t,label = 'Min')
plt.plot(days,avg_t,label = 'Avg')
plt.legend(loc = 'upper right')

# %%
# fontsize = large,small,shadow on the legend
plt.xlabel('days')
plt.ylabel('temperature')
plt.title('weather')
plt.plot(days,max_t,label = 'Max')
plt.plot(days,min_t,label = 'min')
plt.plot(days,avg_t,label = 'avg')
plt.legend(loc = 'best',shadow = True,fontsize = 'small')

# %%
# fontsize = large,small,shadow on the legend
plt.xlabel('days')
plt.ylabel('temperature')
plt.title('weather')
plt.plot(days,max_t,label = 'Max')
plt.plot(days,min_t,label = 'min')
plt.plot(days,avg_t,label = 'avg')
plt.legend(loc = 'best',shadow = True,fontsize = 'small')
plt.grid()
